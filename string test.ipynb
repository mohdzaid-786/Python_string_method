# %%
#1 concatenate
name1="hey"
name2="zain"
string=name1+name2
print(string)
# Out:
# heyzain

# %%
#2 
string="hey","all of you"
text='@'.join(string)
print(text)
# Out:
# hey@all of you

# %%
#3
string="hey zaid"
string.find("zaid")
# Out:
# 4

# %%
#4
string= "this is python class "
string.upper()
# Out:
# 'THIS IS PYTHON CLASS '

# %%
#5
string="this is my code"
string.upper()
# Out:
# 'THIS IS MY CODE'

# %%
#6
string="this is my string test"
string.lower()
# Out:
# 'this is my string test'

# %%
#7
string="hey my name is zaid"
string.replace("zaid","nazaf")
# Out:
# 'hey my name is nazaf'

# %%
#8
string="this is my string test"
string.split(" ",)
# Out:
# ['this', 'is', 'my', 'string', 'test']

# %%
#9
string="this is my string test"
string.startswith("this")
# Out:
# True

# %%
#10
string="ths is my string test"
string.endswith("test")
# Out:
# True

# %%
#11
string="        this is my string test"
string.strip()
# Out:
# 'this is my string test'

# %%
#12
string="this is my string test"
string.find("test")
# Out:
# 18

# %%
#13
string="ths is my string test"
string.count("string")
# Out:
# 1

# %%
#14
string="this is my string test"
string.isalpha()
# Out:
# False

# %%
#15
string="this is my string test"
string.isnumeric()
# Out:
# False

# %%
#17
string="this is my string test"
string.isnumeric()
# Out:
# False

# %%
#18
name="zaiduu"
age=23
string="my name is {}and{}year old".format(name,age)
string.format
# Out:
# <function str.format(*args, **kwargs)>

# %%
#19
string="this is python class"
string[0:18:]
# Out:
# 'this is python cla'

# %%
#20
string="this is string class"
string.replace("class","")
# Out:
# 'this is string '
