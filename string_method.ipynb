# %%
string="this is python class"

# %% [markdown]
# # string.capitalize()

# %%
string="this is python class"
string.capitalize()
# Out:
# 'This is python class'

# %% [markdown]
# # string.casefold()

# %%
string="this is python class"
string.casefold()
# Out:
# '    this is python class'

# %% [markdown]
# # string.center()

# %%
string="this is python class" 
string.center(10)
# Out:
# 'this is python class'

# %% [markdown]
# # string.encode()

# %%
string="this is python class"
string.encode()
# Out:
# b'this is python class'

# %% [markdown]
# # string.endswith()

# %%
string="this is python class"
string.endswith("s")
# Out:
# True

# %% [markdown]
# # string.expandtabs()

# %%
string="this is python class"
string.expandtabs()
# Out:
# 'this is python class'

# %% [markdown]
# # str.find()

# %%
string="this is python class"
string.find("class")
# Out:
# 15

# %% [markdown]
# # string.format()

# %%
string="this is python class"
string.format("class")
# Out:
# 'this is python class'

# %% [markdown]
# # string.format_map()

# %%
string="this is python class"
string.format_map('{''}')
# Out:
# 'this is python class'

# %% [markdown]
# # string.index()

# %%
string="this is python class"
string.index("is")
# Out:
# 2

# %% [markdown]
# # string.isalnum()

# %%
string="this is python class"
string.isalnum()
# Out:
# False

# %% [markdown]
# # string.isalpha()

# %%
string="this is python class"
string.isalpha()
# Out:
# False

# %% [markdown]
# # string.isascii()

# %%
string="this is python class"
string.isascii()
# Out:
# True

# %% [markdown]
# # string.isdecimal()

# %%
string="this is python class"
string.isdecimal()
# Out:
# False

# %% [markdown]
# # string.isdigit()

# %%
string="this is python class"
string.isdigit()
# Out:
# False

# %% [markdown]
# # string.isidentifier()

# %%
string="this is python class"
string.isidentifier()
# Out:
# False

# %% [markdown]
# # string.islower()

# %%
string="this is python class"
string.islower()
# Out:
# True

# %% [markdown]
# # string.isnumeric()

# %%
string="this is pyton class"
string.isnumeric()
# Out:
# False

# %% [markdown]
# # string.isprintable()

# %%
string="this is python class"
string.isprintable()
# Out:
# True

# %% [markdown]
# # string.isspace()

# %%
string="this is python class"
string.isspace()
# Out:
# False

# %% [markdown]
# # string.istitle()

# %%
string="this is python class"
string.istitle()
# Out:
# False

# %% [markdown]
# # string.isupper()

# %%
string="this is python class"
string.isupper()
# Out:
# False

# %% [markdown]
# # string.join()

# %%
string="this is python class"
string.join(['class'])
# Out:
# 'class'

# %% [markdown]
# # string.ljust()

# %%
string="this is python class"
string.ljust(10,'*')
# Out:
# 'this is python class'

# %% [markdown]
# # string.lower()

# %%
string="THIS IS PYTHON CLASS"  
string.lower()
# Out:
# 'this is python class'

# %% [markdown]
# # string.lstrip()

# %%
string="this is python class"
string.lstrip()
# Out:
# 'this is python class'

# %% [markdown]
# # string.maketrans()

# %% [markdown]
# # str.partition()

# %%
string="username=zaid"
string.partition("=")
# Out:
# ('username', '=', 'zaid')

# %% [markdown]
# # string.removeprefix()

# %%
string="unhappy"
string.removeprefix("un")
# Out:
# 'happy'

# %% [markdown]
# # string.removesuffix()

# %%
string="filename.txt"
string.removesuffix(".txt")
# Out:
# 'filename'

# %% [markdown]
# # string.replace()

# %%
string="I like apples"
string.replace("apples","mangoes")
# Out:
# 'I like mangoes'

# %% [markdown]
# # string.rfind()

# %%
string="hello zaid hello"
string.rfind("zaid")
# Out:
# 6

# %% [markdown]
# # string.rindex()

# %%
string="hello zaid hello"
string.rindex("zaid")
# Out:
# 6

# %% [markdown]
# # string.rjust()

# %%
string="python"
string.rjust(10)
# Out:
# '    python'

# %% [markdown]
# # string.rpartition()

# %%
string="apple-banana-orange"
string.rpartition("-")
# Out:
# ('apple-banana', '-', 'orange')

# %% [markdown]
# # string.rsplit()

# %%
string="a-b-c-d"
string.rsplit("-")
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# # string.split()

# %%
string="apple banana orange"
string.split()
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# # string.splitlines()

# %%
string="zaid\nzaiduu"
string.splitlines()
# Out:
# ['zaid', 'zaiduu']

# %% [markdown]
# # string.strip()

# %%
string="this is python class"
string.strip()
# Out:
# 'this is python class'

# %% [markdown]
# # string.swapcase()

# %%
string="this is python class"
string.swapcase()
# Out:
# 'THIS IS PYTHON CLASS'

# %% [markdown]
# # string.title()

# %%
text="hello zaid"
print(text.title())
# Out:
# Hello Zaid

# %% [markdown]
# # string.translate()

# %%
text="hello world"
table=str.maketrans("","","lo")
print(text.translate(table))
# Out:
# he wrd

# %% [markdown]
# # str.upper()

# %%
text="hey zaiduu"
print(text.upper())
# Out:
# HEY ZAIDUU

# %% [markdown]
# # str.zfill()
